# %%
import torch
import cv2
import numpy as np
from PIL import Image
from pathlib import Path

# Paths
gpen_path = "pretrained_weights/gpen/GPEN-512.pth"
retina_path = "pretrained_weights/gpen/RetinaFace-R50.pth"
clean_folder = Path(r"C:\Users\DELL\Desktop\Projet_FaceDenoising\data\test\clean")
noisy_root = Path(r"C:\Users\DELL\Desktop\Projet_FaceDenoising\outputs\test_noise2")
output_root = Path(r"C:\Users\DELL\Desktop\Projet_FaceDenoising\outputs\gpen_results")
output_root.mkdir(parents=True, exist_ok=True)

# Load GPEN (use your notebook's model loading code)
# checkpoint = torch.load(gpen_path, map_location='cuda')
